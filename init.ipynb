# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting APIMakeSens
#   Downloading APIMakeSens-1.0.4.tar.gz (16 kB)
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
# Collecting ipywidgets==7.7.0
#   Downloading ipywidgets-7.7.0-py2.py3-none-any.whl (123 kB)
# Requirement already satisfied: pandas in /shared-libs/python3.7/py/lib/python3.7/site-packages (from APIMakeSens->-r ./requirements.txt (line 1)) (1.2.5)
# Requirement already satisfied: requests in /shared-libs/python3.7/py/lib/python3.7/site-packages (from APIMakeSens->-r ./requirements.txt (line 1)) (2.27.1)
# Collecting datetime
#   Downloading DateTime-4.4-py2.py3-none-any.whl (51 kB)
# Requirement already satisfied: seaborn>=0.10.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas-profiling->-r ./requirements.txt (line 2)) (0.11.2)
# Requirement already satisfied: numpy>=1.16.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas-profiling->-r ./requirements.txt (line 2)) (1.21.6)
# Collecting missingno>=0.4.2
#   Downloading missingno-0.5.1-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: jinja2>=2.11.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pandas-profiling->-r ./requirements.txt (line 2)) (2.11.3)
# Collecting visions[type_image_path]==0.7.4
#   Downloading visions-0.7.4-py3-none-any.whl (102 kB)
# Requirement already satisfied: tqdm>=4.48.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas-profiling->-r ./requirements.txt (line 2)) (4.64.0)
# Collecting htmlmin>=0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
# Collecting phik>=0.11.1
#   Downloading phik-0.12.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (690 kB)
# Requirement already satisfied: PyYAML>=5.0.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas-profiling->-r ./requirements.txt (line 2)) (6.0)
# Requirement already satisfied: matplotlib>=3.2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas-profiling->-r ./requirements.txt (line 2)) (3.5.1)
# Collecting tangled-up-in-unicode==0.2.0
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
# Requirement already satisfied: joblib~=1.1.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas-profiling->-r ./requirements.txt (line 2)) (1.1.0)
# Collecting markupsafe~=2.1.1
#   Downloading MarkupSafe-2.1.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting multimethod>=1.4
#   Downloading multimethod-1.8-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: pydantic>=1.8.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas-profiling->-r ./requirements.txt (line 2)) (1.8.2)
# Requirement already satisfied: scipy>=1.4.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas-profiling->-r ./requirements.txt (line 2)) (1.7.3)
# Collecting widgetsnbextension~=3.6.0
#   Downloading widgetsnbextension-3.6.0-py2.py3-none-any.whl (1.6 MB)
# Collecting jupyterlab-widgets>=1.0.0; python_version >= "3.6"
#   Downloading jupyterlab_widgets-1.1.0-py3-none-any.whl (245 kB)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (7.32.0)
# Requirement already satisfied: traitlets>=4.3.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (4.3.3)
# Requirement already satisfied: ipykernel>=4.5.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (5.5.5)
# Requirement already satisfied: nbformat>=4.2.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (5.1.3)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas->APIMakeSens->-r ./requirements.txt (line 1)) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pandas->APIMakeSens->-r ./requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->APIMakeSens->-r ./requirements.txt (line 1)) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->APIMakeSens->-r ./requirements.txt (line 1)) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests->APIMakeSens->-r ./requirements.txt (line 1)) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests->APIMakeSens->-r ./requirements.txt (line 1)) (3.3)
# Requirement already satisfied: zope.interface in /shared-libs/python3.7/py/lib/python3.7/site-packages (from datetime->APIMakeSens->-r ./requirements.txt (line 1)) (5.4.0)
# Requirement already satisfied: attrs>=19.3.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling->-r ./requirements.txt (line 2)) (21.4.0)
# Collecting networkx>=2.4
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
# Requirement already satisfied: Pillow; extra == "type_image_path" in /shared-libs/python3.7/py/lib/python3.7/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling->-r ./requirements.txt (line 2)) (9.1.0)
# Collecting imagehash; extra == "type_image_path"
#   Downloading ImageHash-4.2.1.tar.gz (812 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=3.2.0->pandas-profiling->-r ./requirements.txt (line 2)) (3.0.8)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=3.2.0->pandas-profiling->-r ./requirements.txt (line 2)) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=3.2.0->pandas-profiling->-r ./requirements.txt (line 2)) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=3.2.0->pandas-profiling->-r ./requirements.txt (line 2)) (4.33.3)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=3.2.0->pandas-profiling->-r ./requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pydantic>=1.8.1->pandas-profiling->-r ./requirements.txt (line 2)) (4.2.0)
# Requirement already satisfied: notebook>=4.4.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (6.3.0)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /root/venv/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (47.1.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (3.0.29)
# Requirement already satisfied: jedi>=0.16 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (0.17.2)
# Requirement already satisfied: pickleshare in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (0.7.5)
# Requirement already satisfied: backcall in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: decorator in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (5.1.1)
# Requirement already satisfied: matplotlib-inline in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (0.1.3)
# Requirement already satisfied: pygments in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (2.12.0)
# Requirement already satisfied: six in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from traitlets>=4.3.1->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: jupyter-client in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (6.1)
# Requirement already satisfied: jupyter-core in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (4.7.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (3.2.0)
# Collecting PyWavelets
#   Downloading PyWavelets-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.4 MB)
# Requirement already satisfied: Send2Trash>=1.5.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (0.13.3)
# Requirement already satisfied: argon2-cffi in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (21.3.0)
# Requirement already satisfied: prometheus-client in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (0.14.1)
# Requirement already satisfied: nbconvert==6.0.7 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (6.0.7)
# Requirement already satisfied: pyzmq>=17 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (22.3.0)
# Requirement already satisfied: ptyprocess>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: wcwidth in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (0.2.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jedi>=0.16->ipython>=4.0.0; python_version >= "3.3"->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (0.7.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (0.18.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (4.11.3)
# Requirement already satisfied: argon2-cffi-bindings in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (21.2.0)
# Requirement already satisfied: bleach in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (5.0.0)
# Requirement already satisfied: defusedxml in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (0.2.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (0.5.9)
# Requirement already satisfied: entrypoints>=0.2.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (0.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: testpath in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (0.6.0)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (3.8.0)
# Requirement already satisfied: cffi>=1.0.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (1.15.0)
# Requirement already satisfied: webencodings in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from bleach->nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (0.5.1)
# Requirement already satisfied: nest-asyncio in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (1.5.5)
# Requirement already satisfied: pycparser in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 3)) (2.21)
# Building wheels for collected packages: APIMakeSens, htmlmin, imagehash
#   Building wheel for APIMakeSens (setup.py): started
#   Building wheel for APIMakeSens (setup.py): finished with status 'done'
#   Created wheel for APIMakeSens: filename=APIMakeSens-1.0.4-py3-none-any.whl size=16520 sha256=75a1cec7d9d8903ffa84f52f4c9100f71eb8322e0060a27046771e5aa0ad8081
#   Stored in directory: /root/.cache/pip/wheels/74/b7/f7/3050beaf8d27fd0621ce6e29ac3a88e513b565b7479b238ebf
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27085 sha256=5fca1388a2bf2798b2593e5c160ce0a60c7af571cd2a854f886e058cf95aa46f
#   Stored in directory: /root/.cache/pip/wheels/70/e1/52/5b14d250ba868768823940c3229e9950d201a26d0bd3ee8655
#   Building wheel for imagehash (setup.py): started
#   Building wheel for imagehash (setup.py): finished with status 'done'
#   Created wheel for imagehash: filename=ImageHash-4.2.1-py2.py3-none-any.whl size=295197 sha256=54d8d64b0e374e45f7a1a6f77703505d11aaea5e16b827a7633028b96940d275
#   Stored in directory: /root/.cache/pip/wheels/4c/d5/59/5e3e297533ddb09407769762985d134135064c6831e29a914e
# Successfully built APIMakeSens htmlmin imagehash
# Installing collected packages: datetime, APIMakeSens, missingno, tangled-up-in-unicode, networkx, multimethod, PyWavelets, imagehash, visions, htmlmin, phik, markupsafe, pandas-profiling, widgetsnbextension, jupyterlab-widgets, ipywidgets
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 2.0.1
#     Not uninstalling markupsafe at /shared-libs/python3.7/py-core/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'MarkupSafe'. No files were found to uninstall.
# Successfully installed APIMakeSens-1.0.4 PyWavelets-1.3.0 datetime-4.4 htmlmin-0.1.12 imagehash-4.2.1 ipywidgets-7.7.0 jupyterlab-widgets-1.1.0 markupsafe-2.1.1 missingno-0.5.1 multimethod-1.8 networkx-2.6.3 pandas-profiling-3.2.0 phik-0.12.2 tangled-up-in-unicode-0.2.0 visions-0.7.4 widgetsnbextension-3.6.0
# ERROR: spacy 3.2.4 has requirement typing-extensions<4.0.0.0,>=3.7.4; python_version < "3.8", but you'll have typing-extensions 4.2.0 which is incompatible.
# WARNING: You are using pip version 20.1.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=062b3a81-0cc0-4bcf-92bb-46d6de867dd8' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
